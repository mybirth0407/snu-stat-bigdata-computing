# %% [markdown]
# ## 03. GitHub

# %% [markdown]
# ### git and GitHub

# %% [markdown]
# git은 버전 관리 시스템이고, [GitHub](https://github.com)는 git으로 관리하는 프로젝트를 올려둘 수 있는 웹 사이트입니다. git은 파일의 변경 사항에 대해 언제, 누가, 무엇을, 어떻게 변경했는지를 비교할 수 있는 스냅샷 기반의 분산 버전 관리 시스템으로 프로그램 개발 과정에서 소스 코드를 관리하고 협업을 도와주는 도구입니다. GitHub는 git으로 관리하는 프로젝트를 올리고 공유할 수 있는 대표적인 git 호스팅 사이트 (원격 저장소) 중 하나입니다. 다른 호스팅 사이트로는 [Bitbucket](https://bitbucket.org/), [GitLab](https://about.gitlab.com/)  등이 있습니다. GitHub은 이러한 호스팅 사이트 중 거의 표준에 가까운 서비스입니다. git은 컴퓨터 파일 시스템을 추적 대상으로 하기 때문에 파일 시스템이 구성된 장치라면 어디에서나 사용할 수 있습니다. USB에 .git 디렉토리가 있다면, USB를 연결한 저장 공간에서도 git을 사용할 수 있습니다. 따라서, git 기능이 포함된 웹 호스팅 서버가 존재한다면, 웹을 통해 여러 사람들과 함께 협업이 가능합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# git을 비롯하여 버전이과 백업을 관리해주는 Dropbox, Onedrive, Google Drive와 같은 클라우드 서비스들은 모두 클라이언트-서버 구조를 가지고 있습니다. 여기서 클라이언트는 우리가 각 웹 사이트에서 다운로드받는 프로그램 입니다. 즉, 서비스의 사용자는 클라이언트-서버 구조 중 클라이언트에 해당합니다.
#
# 예를 들어 Onedrive의 클라이언트로써 우리가 프로그램을 사용하는 방식을 생각해보면, 우리는 간단히 파일을 만들고 저장하고, 단지 그것만 수행합니다. 그러면, 서버는 어떤 일을 할까요? 서버는 사용자가 저장한 파일을 서버에 입력받아, **가능한 실시간에 가깝게, 가능한 충돌이 발생하지 않게 저장 및 버저닝**한 후, 파일을 사용하는 사용자가 해당 파일을 요청하면 파일을 전송합니다.
#
# git의 관점으로 바라보면, 우리의 로컬 git 저장소는 하나의 클라이언트,  GitHub는 서버의 역할을 합니다. 우리가 로컬 git 저장소에서 `git add`, `git commit`과 같은 명령어들을 이용하여 작업한 결과물들을 `git push` 명령어를 이용하여 GitHub 로 전송합니다. GitHub 서버는 우리가 전송한 git 저장소를 가능한 실시간에 가깝게, 가능한 충돌이 발생하지 않게 저장합니다. 그리고 저장된 git 저장소를 웹에 공개합니다. 본 부트캠프의 강의 자료들이 올라가있는 웹 사이트가 바로 GitHub입니다.
#
# 우리가 지난 git 수업시간에서 다룬 내용을 생각해보면, 로컬의 git 저장소만 이용했기 때문에, 다른 사람들에게 공유하지 못했습니다. 이번 시간에는 다른 사람들과 공유할 수 있는 GitHub의 원격 저장소 기능을 활용해볼 것입니다.

# %% [markdown]
# ### GitHub for Career

# %% [markdown]
# 단순하게는 GitHub은 git의 원격 저장소로써 활용되고, 소스 코드 혹은 어떠한 자료들을 웹 상에 공개하는 것으로 생각할 수 있습니다. 그런데, 이러한 이유로 어떠한 시점부터 많은 소프트웨어 회사들은 채용 시에 지원자의 GitHub 링크를 작성하는 것을 적극 권장하고, 일부 스타트업들은 GitHub 링크 제출을 의무화하고 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# GitHub는 개발자, 분석가, 디자이너 등의 이력서 및 포트폴리오를 상당수 대체해주는 역할을 하고 있습니다. 지원자가 1) *git을 활용하여 어떤 프로젝트를 진행해왔는지*, 2) *git을 잘 활용할 줄 아는지*, 3) *협업 경험이 있는지* 등 GitHub에는 많은 나의 정보들을 기록해두고 이를 채용에 활용할 수 있습니다. 또한 GitHub는 *github.io* 라는 웹 호스팅 서비스도 지원하고 있어, 이를 활용하여 간단한 블로그 혹은 개인 웹 사이트를 만드는 것도 가능합니다.

# %% [markdown]
# GitHub를 활용한 [이력서의 좋은 예시](https://github.com/1pha), github.io를 활용한 [하이퍼커넥트 기술 블로그](https://hyperconnect.github.io/)

# %% [markdown]
# 연구자에게도 GitHub는 강력한 기회들을 제공합니다. 예를 들면, GitHub를 통해 연구를 쉽게 공유하고, 공유받을 수 있으며 공개된 연구의 내용대로 잘 동작하는지 직접 테스트하는 것도 가능합니다. git으로 잘 관리된 프로젝트의 경우 커밋 메세지를 통해 연구 과정과 중간 결과물들도 확인할 수 있습니다. GitHub을 통해 진행되고 있는 오픈 소스 프로젝트에 기여하는 것도 가능합니다. 잘 알려진 오픈 소스 프로젝트에 기여했다는 것은 해당 오픈 소스를 잘 활용하고 있고, 문제점 혹은 개선점을 발견하여 해결할 수 있는 기술적 능력이 있다는 이야기므로, 많은 경우에 좋은 커리어로써의 역할을 합니다. 기술적인 기여가 아니더라도, 해당 기술들을 다른 언어로 번역하거나 (영어 $\leftrightarrow$ 한국어, Python2 $\leftrightarrow$ Python3), 오타를 수정하는 것도 오픈소스에 기여하는 좋은 자세입니다.

# %% [markdown]
# 또한 꼭 코드를 기여해야 하는 것은 아닙니다. [과제물들을 잘 정리](https://github.com/mybirth0407/graduate_courses)해둘 수도 있을 것이고, 수업 필기를 업로드하고 공유하는 것도 GitHub를 활용한 커리어 쌓기에 해당됩니다.

# %% [markdown]
# 한국어 번역 기여자가 필요해보이는 [오픈 소스 예시 1](https://github.com/phyver/GameShell), [오픈 소스 예시 2](https://github.com/git-game/git-game-v2)

# %% [markdown]
# ### git and Github for Collaboration

# %% [markdown]
# GitHub에 프로젝트를 올리고 공개 저장소로 설정한다면, 시간, 공간적 제한 없이 전 세계 엔지니어들과 협업할 수 있습니다. 아마 통계학도라면 한번 쯤은 경험해봤을 [RStudio](https://github.com/rstudio/) 또한 GitHub에서 공유되고 있는 오픈 소스 프로젝트입니다. 그 외에도 GitHub를 통해 오픈 소스로 개발되고 있는 프로젝트는 수없이 많습니다.
