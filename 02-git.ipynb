# %% [markdown]
# #### GameShell Mission 29
# 1. `ps -ef | grep spell` 을 통해 **imp**의 spell **PID**를 찾고,
# 2. `kill [PID]` 명령어를 통해 제거
# 3. `~/Castle/Cellar` 디렉토리의 `*_coal` 제거

# %% [markdown]
# ## 02. Git
# ![image.png](attachment:0246d53a-9ed5-4f1d-9f82-bc0db1f18cdb.png)

# %% [markdown]
# ### Open Source
# 오픈 소스란 오픈 소스 소프트웨어 (Open Source Software, OSS)를 뜻하는 용어로, 공개적으로 액세스할 수 있게 설계되어 누구나 자유롭게 확인, 수정, 배포할 수 있는 코드입니다. 오픈 소스는 상위 직급의 평가자가 존재하는 것이 아니라, 커뮤니티 기반의 평가가 이루어지므로, 분산된 동시에 협업 방식으로 개발됩니다. 단일 개발자 혹은 기업이 아닌 커뮤니티 기반으로 개발이 이루어지므로 독점적인 소프트웨어보다 저렴하고, 유연하며, 지속성이 있습니다.
#
# 현 시점에서 오픈 소스 소프트웨어는 단순히 하나의 산출물을 내는 프로덕션 단계를 넘어서 하나의 핵심적인 작업 흐름이 되었습니다. 오픈 소스는 현재 라이선스를 통해 관리되고 있고, 각 라이선스는 [여기](https://www.olis.or.kr/license/compareGuide.do)에서 확인하실 수 있습니다.

# %% [markdown]
# 내가
# 1. 20,000,000 행의 대형 오픈소스 코드
# 2. 30년 가량 지속하고 있는 프로젝트
# 3. 핵심적인 소프트웨어
#
# 를 개발하는 사람이라면?

# %% [markdown]
# 1. 어지럽다.
# 2. 힘들다.
# 3. 부담스럽다.
# 4. 즐겁다.
# 5. 인생에 한 번쯤은 그 정도 규모의 프로젝트를 해보고 싶다.
#
# ...

# %% [markdown]
# 어떤 프로젝트일까요? [정답](https://www.kernel.org/)

# %% [markdown]
# ### Behind Story of git

# %% [markdown]
# 리누스 토발즈는 당시 수십만 줄이 넘어가는 Linux 커널을 개발하고 관리하고 있었음에도, 코드의 버전을 관리하는 소프트웨어를 사용하지 않고 있었습니다. 토발즈가 그러한 소프트웨어를 신뢰할 수 없다는 것이 가장 큰 이유였습니다. 전 세계 사람들이 보내오는 메일로부터 코드와 변경사항, 기여 내용들을 관리하고 있었습니다. 하지만 토발즈도 이러한 상황을 오래 버티지 못하고 [Bitkeeper](http://www.bitkeeper.org/)라는 버전 관리 소프트웨어를 사용했습니다. 하지만 여러가지 문제로 인해, Bitkeeper는 Linux 개발자들을 일부 제한하게 되고, 이에 분노한 토발즈는 Bitkeeper 사용을 중단하고 [git](https://git-scm.com/) 이라는 버전 관리 시스템을 만들었습니다. (TMI: 2주만에 완성되었습니다.) git 또한 Linux와 마찬가지로 오픈 소스 소프트웨어로 개발되었고, 모든 사용자에게 무료로 사용할 수 있도록 공개했습니다.
#
# [리눅스 개발 비화를 그린 만화](https://joone.net/2022/10/02/47-git/)

# %% [markdown]
# 토발즈가 개발했다는 사실만으로 Git은 전 세계인들의 주목을 받았고, 당시 다른 버전 관리 소프트웨어를 모두 누르고 압도적인 점유율을 차지했습니다. 또한 토발즈의 이름값에 모인 뛰어난 개발자들이 버그를 수정하고, 시스템을 개선하는 등 지속적으로 업데이트되며 현재는 거의 모든 오픈소스 소프트웨어가 Git을 이용하여 개발, 관리되고 있습니다.

# %% [markdown]
# 협업을 위한 버전 관리 도구로써의 Git 의 세 가지 핵심적인 기능은 다음과 같습니다.
#
# 1. **버전** 관리: 특정 날짜 혹은 특정 기능이 완성된 버전을 기준으로 이름표를 붙입니다. (예시: v0.1, v0.2, v.remaster, ...)
# 2. **백업** 관리: 특정 날짜의 버전을 저장하고 있습니다. (예시: 1994-04-07, 2023-08-25, 2023-08-29...)
# 3. **협업** 도구: 여러 사람이 버전 관리와 백업 기능을 함께 활용할 수 있습니다. (팀 단위의 협업, 기업 단위의 협업, 연구실 단위의 협업, ...)

# %% [markdown]
# ### What is Version Control Systems?

# %% [markdown]
# **버전 관리 시스템 (VCS, Version Control System)** 은 파일의 변화를 시간 혹은 기능 단위로 기록했다가, 특정 시점의 버전으로 파일을 다시 되돌릴 수 있도록 해주는 시스템입니다. 주로 개발자, 연구자들이 활용하고 있지만, 프로그램의 소스 코드만을 대상으로 하는 것이 아니라 컴퓨터 파일을 대상으로 하기 때문에 그래픽 디자이너, 웹 디자이너, 혹은 문서 작업자들에게도 도움이 되는 도구입니다. 버전 관리 시스템을 이용하면 파일을 이전 상태로 되돌릴 수 있을 뿐만 아니라, 어떤 변경 사항을 추가한 이후로 문제가 생겼는지 추적하는 것도 가능합니다. 과거에 어떤 문제가 발생했고 어떤 사람이 어떻게 해결했는지도 확인할 수 있습니다. 실수로 다른 곳으로 이동시킨 파일들에 대해서도 추적이 가능하거나, 복구가 가능합니다.

# %% [markdown]
# 단순한 의미에서, 우리는 이미 버전 관리를 한번 이상 경험해봤습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 만약, 위와 같은 버전 관리를 여러번 해본 사람이라면 다음과 같이 날짜를 포함하기도 할 것입니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 단순한 구조의 파일들을 관리할 때에는 이러한 방식도 충분할 수 있습니다. 하지만, 여전히 위험한 점이 많습니다. 예를 들어, 디렉토리를 실수로 지워버린 경우에는 모든 파일이 삭제되어 버립니다. 만약, 더 영리한 사람이라면 Google Drive, OneDrive, DropBox 등의 클라우드 저장소를 이용할 것입니다. 하지만 이 또한 오래된 기록을 유지하지 못할 뿐더러 아주 많은 파일이 존재하는 프로젝트라면 언제, 어떤 변경사항이 있었는지 추적하는 것이 어렵습니다.

# %% [markdown]
# #### Importance of Version Control Systems

# %% [markdown]
# 버전 관리의 중요성을 예시를 통해 알아보겠습니다.
#
# 민철이네 연구소는 세상을 뒤바꾸겠다는 창대한 꿈을 안고 프로젝트를 배포하고 있었습니다. 프로젝트의 다섯 번째 버전이 공개되고 나서, 심각한 버그가 발견되었습니다. 구체적으로는 다음과 같은 상황입니다.
#
# 1. 여러 모듈들이 모여 하나의 프로젝트로 배포되고 있습니다.
# 2. 첫 달에는 3개의 모듈을 포함한 프로젝트를 배포했고, 매 달마다 하나의 모듈이 추가되며 배포되고 있습니다.
# 3. 2번째 배포부터 프로젝트 규모가 커져서, 모든 모듈에 대한 테스트를 시행하지 못했습니다.
# 4. 현재 배포판에서 심각한 버그가 발견되었습니다.
#
# 현재 상황에서 어떻게 버그를 찾아낼 수 있을까요?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 버전 관리 소프트웨어를 사용하여 관리하지 않는다면, Version 5의 **모든 모듈들을 살펴봐야 할 것** 입니다. 그런데 만약, 각 모듈들의 소스 코드가 200,000 행 이상이라면 어떻게 될까요? 우리는 800,000 행의 소스 코드를 모두 확인해야 합니다. 소스 코드 한 줄이 수식 한 줄이라고 생각한다면, 얼마나 힘든 검수를 해야 하는지 감이 올 것입니다.

# %% [markdown]
# 하지만 버전 관리 시스템을 사용한다면 어떨까요? 각 버전의 변경점을 상세히 기록해두고, 이전 버전으로 되돌릴 수 있다면, 현재 상황에서 버그를 찾는 것은 상대적으로 간단해집니다.
#
# 1. 먼저, 버전을 한 단계 이전으로 되돌아가 테스트를 시행합니다.
# 2. 이전 버전에서도 문제가 생긴다면 한 단꼐 앞으로 돌아갑니다. 만약, 이전 버전에서 문제가 생기지 않으면, 이전 버전으로 되돌리기 전의 버전이 문제일 것입니다.
# 3. 문제가 발생했던 버전의 변경 사항을 기록한 이력으로부터 확인하고, 해당 부분을 코드에서 찾아 문제점을 확인하고 수정합니다.

# %% [markdown]
# 운이 좋다면, 변경 사항 이력을 통해 금방 문제점을 파악할 수도 있을 것이고, 최악의 경우에도 새로 추가된 모듈만 검사하면 될 것입니다. 즉, 단순 계산으로도 최소 4배 이상의 효율적인 작업이 가능할 것임을 예상할 수 있습니다. 이러한 간단한 상황에서도 버전 관리 시스템은 문제에 대해 굉장히 효율적인 대응이 가능한 것을 알 수 있습니다.

# %% [markdown]
# 한 가지, 다른 예시를 또 생각해볼 수 있습니다.
#
# 정원이네 연구소는 민철이네 연구소의 상황을 듣고, 간단하게라도 버전 관리를 시작했습니다. 정원이네 연구소에서 선택한 방식은 새로 버전이 릴리즈 될 때마다 변경 사항들을 기록하고 있습니다.

# %%
# !tree vcs_example/code
# Out:
# vcs_example/code
# ├── Version1
# │   ├── version1_module1.py
# │   ├── version1_module2.py
# │   ├── version1_module3.py
# │   └── version1_변경사항.txt
# ├── Version2
# │   ├── version2_module1.py
# │   ├── version2_module2.py
# │   ├── version2_module3.py
# │   ├── version2_module4.py
# │   └── version2_변경사항.txt
# ├── Version3
# │   ├── version3_module1.py
# │   ├── version3_module2.py
# │   ├── version3_module3.py
# │   ├── version3_module4.py
# │   ├── version3_module5.py
# │   └── version3_변경사항.txt
# ├── Version4
# │   ├── version4_module1.py
# │   ├── version4_module2.py
# │   ├── version4_module3.py
# │   ├── version4_module4.py
# │   ├── version4_module5.py
# │   ├── version4_module6.py
# │   └── version4_변경사항.txt
# └── Version5
#     ├── version5_module1.py
#     ├── version5_module2.py
#     ├── version5_module3.py
#     ├── version5_module4.py
#     ├── version5_module5.py
#     ├── version5_module6.py
#     ├── version5_module7.py
#     └── version5_변경사항.txt
#
# ...

# %% [markdown]
# 정원이네 연구소는 이러한 버전관리를 통해, 안정적으로 Version 20까지 배포에 성공했습니다. 그런데 각 파일의 크기가 커지면서 문제가 생겼습니다. 정원이네 연구소는 코드 관리를 위한 컴퓨터로 4TB의 하드 디스크를 사용하고 있었는데, 모듈에 대한 모든 코드들을 버전마다 저장하고 있어 컴퓨터의 용량이 부족해진 것입니다. 단순하게는 컴퓨터의 하드 디스크를 추가하는 방법이 있겠지만, 똑똑한 정원이네 연구소 연구원들은 그러한 방법이 지속될 수 없는 방법이라는 것을 깨달았습니다. 이러한 용량 문제는 어떻게 해결할 수 있을까요?

# %% [markdown]
# 버전 관리 소프트웨어는 용량 문제를 방지하기 위해 파일의 백업본을 저장할 때, 이전 버전과 현재 버전간의 차이만을 (difference) 기록합니다. 따라서, 파일에 작은 변경사항이 잦은 경우에도 거의 동일한 파일을 계속해서 저장하지 않습니다. 이러한 방식을 통해 버전 관리 소프트웨어는 저장 용량 차원에서도 효율적인 형태로 고안되었습니다.

# %% [markdown]
# ### History of Version Contol Systems

# %% [markdown]
# 버전 관리 시스템은 프로그램의 복잡성 증가와 함께 필요성이 제기되었고, 어느 시점부터 필수적인 요소로 자리잡았습니다. git 이전의 버전 관리 시스템은 어떻게 구성되었는지, 그리고 왜 현재에는 git이 가장 활발하게 활용되고 있는지 알아봅니다.

# %% [markdown]
# #### Local Version Control Systems

# %% [markdown]
# 가장 먼저 로컬 환경에서만 동작하는, *로컬 버전 관리 시스템 (LVCS, Local Version Control Systems)* 이 고안되었습니다. 프로그램이 복잡하긴 하지만, 1) **혼자 개발할 수 있는 규모거나**, 2) **메일링을 통해 다른 사람의 기여를 직접 체크하는 것**이 가능한 수준에서 활용할 수 있는 시스템입니다. 로컬 버전 관리 시스템은 파일의 변경 사항만을 저장할 수 있어 용량 문제로부터 자유롭기에, 많은 버전을 생성할 수 있습니다. 버전을 많이 생성할 수 있다는 것은, 작은 변경사항에 대한 기록들을 자주 남기며 버저닝을 할 수 있다는 것을 뜻합니다. 따라서 기존에 사람의 기억력에 의존하거나, 수기로 기록되던 것들을 컴퓨터에 저장할 수 있게 해주는 편리한 도구입니다. 대표적인 로컬 버전 관리 프로그램으로는 [RCS (Revision Control System)](https://en.wikipedia.org/wiki/Revision_Control_System) 가 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Centralized Version Control Systems

# %% [markdown]
# 프로그램의 규모가 방대해지고, 더 이상 거대한 프로젝트를 메일로만 관리할 수 없다는 것을 깨달은 개발자들은 더 이상 로컬에서만 버전을 관리해선 안된다고 생각했습니다. 그렇게 새로 고안된 시스템이 *중앙 집중형 버전 관리 시스템 (CVCS, Centralized Version Control Systems)* 입니다. 중앙 집중형 버전 관리 시스템은 로컬 버전 관리 시스템에서 파일과 변경 사항들을 로컬 컴퓨터에서 서버 컴퓨터로 옮긴 것입니다. 로컬 컴퓨터에는 프로젝트의 특정 버전만을 $^*$스냅샷 (Snapshot) 형태로 가지고 있습니다. 여러 사용자들이 각각의 버전을 가지고 있고, 중앙 컴퓨터가 전체 프로젝트의 버전을 제어하는 시스템은 다중 사용자간 협업이 가능하게 만들었지만 여전히 단점들이 존재했습니다.
#
# 1. 서버 컴퓨터에 장애가 발생하면, 모든 버전 관리 시스템은 중단됩니다.
# 2. 버전 관리는 로컬 컴퓨터가 아닌 서버 컴퓨터만을 이용하기 때문에 사용자가 늘어날수록 서버에 과부하가 발생합니다.
# 3. 프로젝트의 변경사항이 자주 발생할 경우, 모든 사용자들이 계속해서 새 버전으로 업데이트해야하는 불편함이 있습니다.
#
# 대표적인 중앙 집중형 버전 관리 시스템으로는 2010년대 중반까지도 사용되었던 [SVN (SubVersioN)](https://tortoisesvn.net/)이 있습니다.
#
# $*$: 컴퓨터의 파일 시스템에 대해 특정 시점을 지정하여 포착한 후 보관하는 기술입니다. 윈도우의 이전 날짜로 복원 기능이 스냅샷을 활용하는 예시입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Distributed Version Control Systems

# %% [markdown]
# Linux 라는 대형 소프트웨어를 개발하던 리누스 토발즈는 이러한 문제점을 해소하며 대형 프로젝트의 버전 관리와 협업을 위해 git을 개발하였습니다. git은 하나의 서버에 의존하는 중앙 집중형 버전 관리 시스템의 단점을 해소하고, 여러 버전에 대한 안정적인 관리와 다수의 사용자간 협업이 가능하도록 하는 *분산 버전 관리 시스템 (DVCS, Distributed Version Control Systems)* 의 형태를 가지고 있습니다. 분산 버전 관리 시스템은 한 대의 서버가 모든 파일의 버전과 변경 사항들에 대한 이력을 독점하는 것을 문제로 보았고, 이를 각 사용자들의 로컬 컴퓨터에 버전 및 백업본을 스냅샷 형태로 저장하는 방식으로 해결하였습니다. 이러한 방식을 통해 사용자들은 서버를 통하지 않고도 스냅샷 형태로 여러 버전에 접근할 수 있고, 새로운 버전을 업로드 하거나 다운로드 할 때에만 서버에 접근하는 방식으로 서버에 부담을 줄일 수 있었습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### git basics

# %% [markdown]
# #### Delta-based vs Snapshot based

# %% [markdown]
# git은 파일의 변화를 기록하는 것이 아니라, 파일 시스템의 스냅샷을 저장하는 방식으로 버전을 기록하고 백업을 생성합니다. 두 방식은 각각의 장단점이 있지만, 관리할 파일의 내용이 많아지고 규모가 커져 복잡해질수록 스냅샷 기반의 방식이 더 안정적이고 빠르게 동작합니다.
#
# 1. 파일의 변화를 기록하는 경우, 특정 버전으로 돌아갈 때 모든 파일의 모든 버전의 변경사항을 확인해야 합니다. 반면, 스냅샷을 이용하는 경우 해당 시점의 파일 시스템 자체로 복원되기 때문에 더 안전하고 더 단순합니다.
# 2. 여러 개의 *분기 (branch)*를 생성하더라도 분기마다 파일을 저장하는 것이 아니라, 스냅샷 기반으로 분기가 생성되기에 분기 이동이 자유롭습니다.
#
# 스냅샷에 대한 자세한 내용은 본 과정의 난이도를 넘어가므로, 여기에서는 스냅샷을 이용한 버전 관리 시스템이 용량과 속도 면에서 더 효율적이라는 것만 기억하고 넘어가도 괜찮습니다.

# %% [markdown]
# 파일의 변화를 기반으로 저장하는 버전 관리 시스템 (delta-based version control)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 시간에 따른 스냅샷을 저장하는 버전 관리 시스템 (snapshot-based version control)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### git Workflows

# %% [markdown]
# git을 이용한 작업 흐름은 다음과 같이 진행됩니다.
#
# 1. 작업 디렉토리를 git 저장소로 변경합니다. `git init` 명령어를 통해 진행합니다.
# 2. 작업 디렉토리에서 git 저장소에 등록하기 전 파일을 선택하여 $^*$*staging area*에 등록합니다. `git add` 명령어를 이용합니다.
# 3. staging area에 등록된 파일들을 로컬 git 추적 대상으로 등록합니다. 여기서는 변경 사항에 대한 내용을 텍스트로 추가할수 있습니다. `git commit` 명령어를 이용하여 진행합니다.
# 4. 로컬 git 저장소의 내용을 원격 git 저장소의 내용으로 전송하여 공유합니다.
#
# $*$ staging area: git이 파일을 추적하기 위해서는 파일이 git 저장소에 등록되어야 합니다. 파일을 git 저장소에 등록하기 전 등록할 파일을 선택하는 단계입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - add: git이 추적할 대상을 staging area에 등록합니다.
# - commit: 변경 이력을 기록할 수 있으며, staging area에 등록된 파일을 git이 추적하도록 합니다.
# - push: 로컬 git 저장소의 내용을 원격 git 저장소로 전송합니다.
# - fetch: 원격 git 저장소의 버전과 로컬 git 저장소의 버전을 비교합니다.
# - checkout: 로컬 git 저장소에 있는 어떤 버전의 스냅샷으로 작업 디렉토리를 변경합니다.
# - merge: 로컬 git 저장소에 있는 어떤 버전의 스냅샷과 작업 디렉토리를 병합합니다.

# %% [markdown]
# #### git Status

# %% [markdown]
# git은 파일을 세 가지 상태로 평가합니다.
#
# 1. Commited: 데이터가 로컬 git 저장소에 저장된 상태입니다.
# 2. Modified: 수정된 파일이 존재하고, 수정 내역이 로컬 git저장소에 저장되지 않은 상태입니다.
# 3. Staged: 수정된 파일을 staging area에 등록했고, commit 대기 중인 상태입니다.

# %% [markdown]
# ![image.png](attachment:dd001bb3-7f97-45fb-821b-e4edd8741421.png)

# %% [markdown]
# ### Practice

# %% [markdown]
# git을 잘 이용하기 위한 GUI 프로그램들이 있습니다. github에서 제공하는 [Github Desktop](https://desktop.github.com/)과 [SourceTree](https://www.sourcetreeapp.com/)가 대표적입니다. 다만, 본 부트캠프에서는 CUI 환경의 컴퓨팅 도구에 익숙해지는 것이 목적이므로 CUI 환경에서 실습을 진행합니다.

# %% [markdown]
# git 환경에 이용할 `git` 디렉토리를 생성하고, 해당 디렉토리로 이동합니다.
# ```bash
# mkdir git
# cd git
# ```

# %% [markdown]
# 디렉토리 내의 파일 목록을 확인합니다.
# ```bash
# ls -al
# ```

# %% [markdown]
# `git` 디렉토리를 git 저장소로 만들어 보겠습니다.
# ```bash
# git init
# ```

# %% [markdown]
# *Initialized empty Git repository in /workspaces/2023-stat-bigdata-computing/git/.git/*
#
# 라는 메세지가 출력되면, `git` 디렉토리를 성공적으로 git 저장소로 만들었다는 뜻입니다. git 저장소로 만들어진 `git` 디렉토리 내의 파일 목록을 다시 한번 확인해 보겠습니다.
# ```bash
# ls -al
# ```

# %% [markdown]
# `.git` 이라는 숨겨진 디렉토리가 생성된 것을 확인할 수 있습니다. 어떤 디렉토리가 git 저장소라면 반드시 `.git` 이라는 숨겨진 디렉토리를 포함합니다.

# %% [markdown]
# 디렉토리가 git 저장소로 변경되면, 해당 디렉토리는 $^*$`main` 브랜치가 됩니다.
#
# $*$: 과거에는 `master` 브랜치였으나, Master-Slave의 노예제도를 연상시킨다는 이유로 `main` 으로 이름이 변경되었습니다. `main` 브랜치로 변경되기 전의 수많은 저장소들은 여전히 `master` 라는 이름의 브랜치를 사용하고 있습니다.

# %% [markdown]
# 첫 번째 커밋을 한번 진행해보도록 하겠습니다. `snu_stat_bootcamp` 이라는 파일을 생성하고, 생성된 파일에 `Hello, git!` 이라는 내용을 작성합니다. `echo` 명령어와 출력 리디렉션인 `>` 기호를 통해 간단하게 파일을 생성할 수 있습니다.
# ```bash
# echo "Hello, git!" > snu_stat_bootcamp
# ```

# %% [markdown]
# git 저장소에 새로운 파일이 추가되었습니다. 현재 git 저장소가 어떤 상태인지 확인해 보겠습니다.
# ```bash
# git status
# ```

# %% [markdown]
# 현재 git 저장소는 snu_stat_bootcamp 파일을 추적하지 않고 있습니다. 해당 파일을 추적 후보로 등록하도록 staging area에 등록합니다.
# ```bash
# git add snu_stat_bootcamp
# ```

# %% [markdown]
# 커밋을 위해서는 로컬 git에 사용할 사용자 정보가 등록되어 있어야 합니다.
# ```bash
# git config --global user.name [NAME]
# git config --global user.email [EMAIL]
# ```

# %% [markdown]
# 다음으로, staging area에 등록된 파일을 추적하도록 로컬 git 저장소에 등록합니다. 여기서는 변경 사항을 텍스트로 기록할 수 있습니다.
# ```bash
# git commit -m "My first commit"
# ```

# %% [markdown]
# 현재 버전까지 파일들이 어떻게 변경되고 있었는지 이력을 확인할 수 있습니다.
# ```bash
# git log
# ```

# %% [markdown]
# 이력을 확인하는 과정은 버전 관리 시스템의 핵심입니다. 따라서 `git log`는 이력을 확인하고 정리하기 위한 많은 옵션들이 있습니다. 그 중 자주 쓰이는 옵션들을 소개합니다. 먼저, `--patch` 옵션입니다. `--patch` 옵션은 각 커밋의 변경사항들의 차이를 보여줍니다. `-n` 옵션을 추가로 넣어주면 최근 n개의 커밋만을 보여줍니다. 이 옵션은 누가 어떤 내용을 커밋했는지 확인할 수 있다는 장점이 있습니다.
#
# ```bash
# git log --patch -[n]
# ```

# %% [markdown]
# `git log --stat` 명령으로는 커밋에 대해 간단한 통계를 보여줍니다.
# ```bash
# git log --stat
# ```

# %% [markdown]
# `--pretty` 옵션은 일부 정보만 출력하거나, 출력 형태를 지정할 수 있습니다.
#
# ```bash
# git log --pretty=[option]
# ```

# %% [markdown]
# `--pretty` 의 인자로는 `oneline`, `short`, `full`, `fuller`이 올 수 있으며, `format:"[FORMAT]"` 형태로 원하는 내용만을 출력할 수도 있습니다. 가능한 `format`의 형태는 다음과 같습니다.
#
# | Specifier | Description of Output      |
# |-----------|----------------------------|
# |%H         | Commit hash                |
# |%h         | Abbreviated commit hash    |
# |%T         | Tree hash                  |
# |%t         | Abbreviated tree hash      |
# |%P         | Parent hashes              |
# |%p         | Abbreviated parent hashes  |
# |%an        | Author name                |
# |%ae        | Author email               |
# |%ad        | Author date                |
# |%ar        | Author date, relative      |
# |%cn        | Committer name             |
# |%ce        | Committer email            |
# |%cd        | Committer date             |
# |%cr        | Committer date, relative   |
# |%s         | Subject                    |

# %% [markdown]
# `git shortlog` 명령어를 이용해 누가 어떤 커밋들을 해왔는지 볼 수 있습니다.
# ```bash
# git shortlog
# ```

# %% [markdown]
# `git branch` 명령어로 새로운 브랜치를 생성하고, `git checkout` 명령어로 해당 브랜치로 이동할 수 있습니다. 새로운 브랜치가 생성될 때에는 현재 브랜치의 현재 커밋을 기점으로 만들어집니다. `git branch`에 생성할 브랜치 이름을 넣지 않고 실행하면 현재 로컬 git 저장소에 있는 브랜치들을 확인할 수 있습니다. `git checkout`은 브랜치, 태그, 커밋명으로도 이동이 가능합니다. 커밋명의 경우 앞 7자리만으로도 이동할 수 있습니다.
#
# ```bash
# git branch bootcamp
# git checkout bootcamp
# git branch
# ```

# %% [markdown]
# `bootcamp` 브랜치에 새로운 파일을 만들어 커밋을 합니다.
#
# ```bash
# echo "day02" > day02.txt
# git add day02.txt
# git commit -m "bootcamp branch"
# ```

# %% [markdown]
# `main` 브랜치로 이동하면 `bootcamp` 브랜치에서 생성했던 day02.txt가 없어진 것을 확인할 수 있습니다.
# ```bash
# git checkout main
# ls -al
# ```

# %% [markdown]
# 커밋은 복잡한 문자들로 이루어져있기 때문에, 커밋명을 그대로 사용한다면 버전 관리에 오히려 혼란이 가중될 수 있습니다. `git tag` 명령어를 통해 태그를 만들 수 있습니다.
#
# ```bash
# git tag v0.1
# ```

# %% [markdown]
# 파일을 하나 더 생성하여 커밋한 후 v0.2 태그를 달아보도록 합니다.
#
# ```bash
# echo "newfile for newtag" > newfile.txt
# git add newfile.txt
# git commit -m "newfile for newtag"
# git tag v0.2
# ```

# %% [markdown]
# 체크아웃 시에 tag 명으로도 이동이 가능합니다. 먼저, bootcamp 브랜치로 이동했다가 v0.2 태그로 이동합니다.
#
# ```bash
# git checkout bootcamp
# git checkout tags/v0.2
# ```

# %% [markdown]
# 다음으로는 git 저장소 내에 git 저장소를 가져올 수 있는 서브모듈 (submodule) 에 대해 알아봅니다. 서브모듈은 A 라는 프로젝트를 수행하던 도중, B 프로젝트의 결과물을 A 프로젝트의 모듈로써 활용해야 하는 경우에 사용할 수 있습니다. 이름 그대로 git 저장소를 git 저장소의 서브모듈로 활용할 수 있습니다. 후반부에 실습할 git-game-v2를 서브모듈로 가져옵니다.
#
# ```bash
# git submodule add https://github.com/git-game/git-game-v2.git
# ```

# %% [markdown]
# 우리가 만들었던 `git` 디렉토리에 `git-game-v2` 라는 다른 프로젝트가 포함되었습니다. git의 상태가 어떻게 변했는지 확인합니다.
# ```bash
# git status
# ```
#
# `.gitmodules` 라는 서브모듈을 관리하는 파일이 생성되었습니다. 내용을 확인해봅니다.
#
# ```bash
# cat .gitmodules
# ```
#
# 서브모듈이 우리의 `git` 로컬 저장소에 등록된 것을 확인할 수 있습니다. 서브모듈은 삭제가 복잡하므로 불필요한 모듈들을 서브모듈로 추가하는 것은 위험합니다.

# %% [markdown]
# ### git-game-v2 실습

# %% [markdown]
# 서브모듈로 가져온 git-game-v2를 실습합니다. 앞에서 배운 명령어들을 이용합니다. 힌트가 있는 경우 **적극적**으로 이용해야 문제를 해결할 수 있습니다.
#
# - Level 1: 계산된 값에서 -4를 한 브랜치로 이동해야 합니다. linux 명령어 이슈가 있어서 그렇다고 합니다.
# - Level 5: Subject로 커밋 메세지를 확인할 수 있습니다.
# - Level 6: 프로그래밍 언어에 익숙하지 않은 경우 [정답](https://scontent-ssn1-1.xx.fbcdn.net/v/t39.30808-6/182086866_2904572866447475_1587090080077232904_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=730e14&_nc_ohc=tto1xSmqa-0AX-HpRyM&_nc_ht=scontent-ssn1-1.xx&oh=00_AfA6dYuc0FDkGxTpNBQiPPA6U68eh9MwU9lfQWKkufHnjw&oe=64F0FC9A)을 보는 게 좋습니다. cat [정답]/README.md 로 내용을 확인하세요.
# - Level 7: `rev-list` 개념은 복잡하여 설명하지 않았습니다. 다만, 문제를 해결하는 데에는 지장 없습니다.
# - Level 8: `cherry-pick` 개념은 복잡하여 설명하지 않았습니다. 요약하면, `git cherry-pick` 을 통해 다른 브랜치의 특정 커밋을 가져올 수 있습니다. 커밋은 앞 7자리만으로도 식별됩니다.
# - Level 9: `bisect` 개념은 실습이 어려워 진행하지 않았습니다. [링크](https://blog.gangnamunni.com/post/understanding_git_bisect/)를 참고하면 문제 해결에 도움이 됩니다.

# %% [markdown]
# git 공부를 더 해보실 분들은 [Git 브랜치 배우기](https://learngitbranching.js.org/?locale=ko)를 수행하시면 더욱 좋습니다.

# %% [markdown]
#  #### Useful command

# %% [markdown]
# `xargs` 명령어와 파이프를 이용하면 `xargs` 뒤의 명령어의 인자로 파이프 앞의 결과물을 가져다 사용할 수 있습니다. 다음 명령어는 `touch`의 인자로 `file1.txt` `file2.txt`, `file3.txt`를 전달합니다.
#
# ```bash
# echo "file1.txt file2.txt file3.txt" | xargs touch
# ```
